# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/MyDrive/benchmark"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n gears python=3.10 -y

# %%
# !pip install argparse numpy session_info cell-gears

# %%
# !pip install torch_geometric

# %%
# !pip install cell-gears

# %%
# !pip install matplotlib-inline
# %matplotlib inline

# %%
# !conda activate gears

# %%
# !pip install "scipy<1.15.0"

# %%
# !python /content/drive/MyDrive/benchmark/src/run_gears.py \
    --dataset_name adamson \
    --test_train_config_id seed_1_adamson_split \
    --working_dir /content/drive/MyDrive/benchmark/output/working_dir \
    --result_id gears_results
# Out:
# Namespace(dataset_name='adamson', test_train_config_id='seed_1_adamson_split', epochs=20, seed=1, working_dir='/content/drive/MyDrive/benchmark/output/working_dir', result_id='gears_results')
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# ...
